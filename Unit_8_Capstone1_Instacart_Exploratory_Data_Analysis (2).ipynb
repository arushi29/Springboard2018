# %% [markdown]
# **Capstone 1  -  Instacart Market Basket Analysis**
#
# Instacart is a U.S. based company that provides same-day grocery delivery service. It provides the customers an option to choose the grocery store they want their groceries through the item list, select the items and get it hand-delivered by a personal shopper. The company offers the services both through their website as well their app.
#
# They have over 3 million transactional data of multiple shoppers located across the United States.
#
# **Problem Statement**
# Instacart wants to leverage this data to build a model that can predict which previously purchased products will be in a user’s next order. This will help the company strategize where to show the previously ordered items on their page or app.The model will also help recommend items for users while they are browsing.

# %%
#Import the necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.stats.weightstats as ssw
import seaborn as sns
import statsmodels.stats.proportion as ssp
color = sns.color_palette()
from scipy.stats import norm
from scipy.stats import normaltest
from statsmodels.stats.weightstats import ztest
from scipy import stats
import math
import statsmodels.stats.api as sms

# %%
#Import the files
#files provided - aisles, products,departments,orders_prior,orders

#aisles
aisles = pd.read_csv('aisles.csv')
#importing the departments file
departments= pd.read_csv('departments.csv')
# importing the products file
#products
products =pd.read_csv("products.csv")
#orders_prior
#importing the orders_prior file
orders_prior =pd.read_csv("order_products__prior.csv")
#5
#importing the orders_train file
order_train = pd.read_csv('order_products__train.csv')
#6 orders
orders = pd.read_csv('orders.csv')

# %%
orders_train_sub = orders[(orders['eval_set'] == 'train')]
len(orders_train_sub)
# Out:
# 131209

# %%
orders_train_sub.head()
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 10   1187899        1    train            11          4                  8
# 25   1492625        2    train            15          1                 11
# 49   2196797        5    train             5          0                 11
# 74    525192        7    train            21          2                 11
# 78    880375        8    train             4          1                 14
#
#     days_since_prior_order
# 10                    14.0
# 25                    30.0
# 49                     6.0
# 74                     6.0
# 78                    10.0

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
orders_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Merging files
#merging product with aisle and department files

products_a = pd.merge(products,aisles,on='aisle_id')

# %%
# merging with departments file
products_all =pd.merge(products_a,departments,left_on = 'department_id'
                       ,right_on = 'department_id',how='left',suffixes = ('_x', '_y'))
products_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49688 entries, 0 to 49687
# Data columns (total 6 columns):
# product_id       49688 non-null int64
# product_name     49688 non-null object
# aisle_id         49688 non-null int64
# department_id    49688 non-null int64
# aisle            49688 non-null object
# department       49688 non-null object
# dtypes: int64(3), object(3)
# memory usage: 2.7+ MB

# %%
#orders table - merge with orders_train to get other variables
orders_all = pd.merge(orders,orders_prior,left_on= 'order_id',right_on='order_id',how="inner",suffixes = ('_x', '_y'))
orders_all = pd.merge(orders_all,products_all,left_on= 'product_id',right_on='product_id',how="inner" )
orders_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32434489 entries, 0 to 32434488
# Data columns (total 15 columns):
# order_id                  int64
# user_id                   int64
# eval_set                  object
# order_number              int64
# order_dow                 int64
# order_hour_of_day         int64
# days_since_prior_order    float64
# product_id                int64
# add_to_cart_order         int64
# reordered                 int64
# product_name              object
# aisle_id                  int64
# department_id             int64
# aisle                     object
# department                object
# dtypes: float64(1), int64(10), object(4)
# memory usage: 3.9+ GB

# %% [markdown]
# **From the previous EDA, we had noticed the following trends**
#
# Most items are ordered from the produce department
#
# Instacart gets more orders on Sundays and Saturdays
#
# Let us check we can prove this statistically
#
# Assuming null hypothesis - There is no difference in the proportion of items from produce department in the orders between the orders that are placed on a weekday and a weekend
#
# Alternate hypothesis - There is a significant difference in the proportion of items from produce department in the orders between the orders that are placed on a weekday and a weekend

# %%
#create the order sets for weekdays and weekend
week = [1,2,3,4,5]
weekend = [0,6]
orders_week = orders_all[orders_all.order_dow.isin(week)]
orders_weekend = orders_all[orders_all.order_dow.isin(weekend)]

# %%
orders_week.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
n1=len(orders_week)
n1
# Out:
# 21724519

# %%
n2= len(orders_weekend)
n2
# Out:
# 10709970

# %%
orders_week_prod
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# 5          3367565        1    prior             6          2
# 6           550135        1    prior             7          1
# 7          3108588        1    prior             8          1
# 8          2295261        1    prior             9          1
# 9          2550362        1    prior            10          4
# 10         2968173       15    prior            15          1
# 11         1870022       15    prior            17          2
# 12         1911383       15    prior            18          2
# 13         2715276       15    prior            21          1
# 14          487368       15    prior            22          1
# 15         2293453       19    prior             2          5
# 16         1973799       19    prior             5          6
# 17          532817       19    prior             7          4
# 18         1573906       21    prior            10          3
# 19         1593000       31    prior            10          3
# 20         2231262       31    prior            17          3
# 21         2580647       43    prior             6          4
# 22         2187180       43    prior             9          4
# 23         2497897       52    prior             1          1
# 24         1318871       52    prior             2          1
# 25         1261384       52    prior             3          1
# 26          580568       52    prior             5          2
# 27         2428073       52    prior             7          2
# 28          342306       52    prior             9          1
# 29         1520353       52    prior            10          2
# ...            ...      ...      ...           ...        ...
# 32434459    131322   193840    prior             3          0
# 32434460   2990238   194078    prior             4          1
# 32434461   3294485   202763    prior            27          0
# 32434462   2706073   194639    prior            25          5
# 32434463    346319   196040    prior             9          3
# 32434464    828012   196359    prior             2          1
# 32434465   2608655   197349    prior             1          3
# 32434466   3004721   197459    prior             2          4
# 32434467   2216423   198107    prior             2          5
# 32434468    136517   198107    prior             4          1
# 32434469    461844   200351    prior             5          2
# 32434470    216145   205587    prior             1          3
# 32434471   2941852   200463    prior             2          1
# 32434472   2321285   203389    prior            16          2
# 32434473    609055   202557    prior             1          0
# 32434474   1928449   202557    prior             4          4
# 32434475   2222639   202557    prior             6          5
# 32434476    339942   202557    prior             8          4
# 32434477   2798193   202557    prior             9          4
# 32434478   2391791   202557    prior            11          6
# 32434479    576295   202557    prior            12          3
# 32434480    960088   202557    prior            13          4
# 32434481    343962   202557    prior            14          0
# 32434482   2329472   202557    prior            15          6
# 32434483    694731   202557    prior            16          1
# 32434484   1320836   202557    prior            17          2
# 32434485     31526   202557    prior            18          5
# 32434486    758936   203436    prior             1          2
# 32434487   2745165   203436    prior             2          3
# 32434488   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# 2                        12                    21.0         196
# 3                         7                    29.0         196
# 4                        15                    28.0         196
# 5                         7                    19.0         196
# 6                         9                    20.0         196
# 7                        14                    14.0         196
# 8                        16                     0.0         196
# 9                         8                    30.0         196
# 10                        9                     7.0         196
# 11                       16                     8.0         196
# 12                       11                     7.0         196
# 13                        9                     7.0         196
# 14                       10                    14.0         196
# 15                       14                     6.0         196
# 16                       12                     8.0         196
# 17                       17                     6.0         196
# 18                       10                     6.0         196
# 19                        8                     7.0         196
# 20                       11                     8.0         196
# 21                       16                     4.0         196
# 22                       12                     3.0         196
# 23                        9                     NaN         196
# 24                       10                     7.0         196
# 25                       10                     7.0         196
# 26                       10                     8.0         196
# 27                        7                     8.0         196
# 28                       11                     7.0         196
# 29                       10                     8.0         196
# ...                     ...                     ...         ...
# 32434459                 14                    12.0       19259
# 32434460                 13                    10.0       40747
# 32434461                 16                    30.0       40747
# 32434462                 11                    16.0       45378
# 32434463                 16                    16.0       35952
# 32434464                  7                     8.0       48343
# 32434465                 15                     NaN        9818
# 32434466                 20                     4.0       44495
# 32434467                 16                     7.0       29713
# 32434468                 13                     8.0       29713
# 32434469                 11                     9.0       15408
# 32434470                 14                     NaN       15408
# 32434471                 15                    30.0        8682
# 32434472                 10                     6.0        8682
# 32434473                 13                     NaN       43553
# 32434474                  9                    16.0       43553
# 32434475                  9                     4.0       43553
# 32434476                 10                     4.0       43553
# 32434477                 13                     7.0       43553
# 32434478                  6                     8.0       43553
# 32434479                 10                    11.0       43553
# 32434480                 12                    15.0       43553
# 32434481                 10                     3.0       43553
# 32434482                 12                     6.0       43553
# 32434483                 14                     2.0       43553
# 32434484                 15                     1.0       43553
# 32434485                 11                     3.0       43553
# 32434486                  7                     NaN       42338
# 32434487                  5                    15.0       42338
# 32434488                 14                     NaN       28818
#
#           add_to_cart_order  reordered  \
# 0                         1          0
# 1                         1          1
# 2                         1          1
# 3                         1          1
# 4                         1          1
# 5                         1          1
# 6                         1          1
# 7                         2          1
# 8                         4          1
# 9                         1          1
# 10                        2          0
# 11                        6          1
# 12                        1          1
# 13                        1          1
# 14                        1          1
# 15                        3          0
# 16                       15          1
# 17                        1          1
# 18                        2          0
# 19                       17          0
# 20                       14          1
# 21                        9          0
# 22                        1          1
# 23                        4          0
# 24                        5          1
# 25                        3          1
# 26                        6          1
# 27                        5          1
# 28                        5          1
# 29                        4          1
# ...                     ...        ...
# 32434459                 10          0
# 32434460                 29          0
# 32434461                 13          0
# 32434462                 10          0
# 32434463                 13          0
# 32434464                  6          0
# 32434465                  9          0
# 32434466                  1          0
# 32434467                  4          0
# 32434468                  3          1
# 32434469                  2          0
# 32434470                  6          0
# 32434471                 11          0
# 32434472                  7          0
# 32434473                  2          0
# 32434474                  4          1
# 32434475                  3          1
# 32434476                  3          1
# 32434477                  5          1
# 32434478                  2          1
# 32434479                 14          1
# 32434480                  3          1
# 32434481                  2          1
# 32434482                  2          1
# 32434483                  2          1
# 32434484                  2          1
# 32434485                  2          1
# 32434486                  4          0
# 32434487                 16          1
# 32434488                  8          0
#
#                                                product_name  aisle_id  \
# 0                                                      Soda        77
# 1                                                      Soda        77
# 2                                                      Soda        77
# 3                                                      Soda        77
# 4                                                      Soda        77
# 5                                                      Soda        77
# 6                                                      Soda        77
# 7                                                      Soda        77
# 8                                                      Soda        77
# 9                                                      Soda        77
# 10                                                     Soda        77
# 11                                                     Soda        77
# 12                                                     Soda        77
# 13                                                     Soda        77
# 14                                                     Soda        77
# 15                                                     Soda        77
# 16                                                     Soda        77
# 17                                                     Soda        77
# 18                                                     Soda        77
# 19                                                     Soda        77
# 20                                                     Soda        77
# 21                                                     Soda        77
# 22                                                     Soda        77
# 23                                                     Soda        77
# 24                                                     Soda        77
# 25                                                     Soda        77
# 26                                                     Soda        77
# 27                                                     Soda        77
# 28                                                     Soda        77
# 29                                                     Soda        77
# ...                                                     ...       ...
# 32434459          Florentine Spinach and Cheese Pasta Sauce         9
# 32434460  Whitening Plus Scope Crest Complete Multi-Bene...        20
# 32434461  Whitening Plus Scope Crest Complete Multi-Bene...        20
# 32434462                           Miss Treated Conditioner        22
# 32434463                                 Peachtree Schnapps       124
# 32434464                             Hennepin Farmhouse Ale        27
# 32434465                                  Cld/Flu Van Chrry        11
# 32434466  Lowfat Cherry Lime Supernova Kefir Cultured Mi...       120
# 32434467                              18 Year Scotch Whisky       124
# 32434468                              18 Year Scotch Whisky       124
# 32434469  Training  Fluoride Free Toothpaste Apple & Ban...        20
# 32434470  Training  Fluoride Free Toothpaste Apple & Ban...        20
# 32434471                                 All Purpose Eraser       114
# 32434472                                 All Purpose Eraser       114
# 32434473                                Orange Energy Shots        64
# 32434474                                Orange Energy Shots        64
# 32434475                                Orange Energy Shots        64
# 32434476                                Orange Energy Shots        64
# 32434477                                Orange Energy Shots        64
# 32434478                                Orange Energy Shots        64
# 32434479                                Orange Energy Shots        64
# 32434480                                Orange Energy Shots        64
# 32434481                                Orange Energy Shots        64
# 32434482                                Orange Energy Shots        64
# 32434483                                Orange Energy Shots        64
# 32434484                                Orange Energy Shots        64
# 32434485                                Orange Energy Shots        64
# 32434486                              Zucchini Chips, Pesto        50
# 32434487                              Zucchini Chips, Pesto        50
# 32434488                      Hot Oatmeal Multigrain Raisin       130
#
#           department_id                     aisle       department
# 0                     7               soft drinks        beverages
# 1                     7               soft drinks        beverages
# 2                     7               soft drinks        beverages
# 3                     7               soft drinks        beverages
# 4                     7               soft drinks        beverages
# 5                     7               soft drinks        beverages
# 6                     7               soft drinks        beverages
# 7                     7               soft drinks        beverages
# 8                     7               soft drinks        beverages
# 9                     7               soft drinks        beverages
# 10                    7               soft drinks        beverages
# 11                    7               soft drinks        beverages
# 12                    7               soft drinks        beverages
# 13                    7               soft drinks        beverages
# 14                    7               soft drinks        beverages
# 15                    7               soft drinks        beverages
# 16                    7               soft drinks        beverages
# 17                    7               soft drinks        beverages
# 18                    7               soft drinks        beverages
# 19                    7               soft drinks        beverages
# 20                    7               soft drinks        beverages
# 21                    7               soft drinks        beverages
# 22                    7               soft drinks        beverages
# 23                    7               soft drinks        beverages
# 24                    7               soft drinks        beverages
# 25                    7               soft drinks        beverages
# 26                    7               soft drinks        beverages
# 27                    7               soft drinks        beverages
# 28                    7               soft drinks        beverages
# 29                    7               soft drinks        beverages
# ...                 ...                       ...              ...
# 32434459              9               pasta sauce  dry goods pasta
# 32434460             11              oral hygiene    personal care
# 32434461             11              oral hygiene    personal care
# 32434462             11                 hair care    personal care
# 32434463              5                   spirits          alcohol
# 32434464              5             beers coolers          alcohol
# 32434465             11          cold flu allergy    personal care
# 32434466             16                    yogurt       dairy eggs
# 32434467              5                   spirits          alcohol
# 32434468              5                   spirits          alcohol
# 32434469             11              oral hygiene    personal care
# 32434470             11              oral hygiene    personal care
# 32434471             17         cleaning products        household
# 32434472             17         cleaning products        household
# 32434473              7      energy sports drinks        beverages
# 32434474              7      energy sports drinks        beverages
# 32434475              7      energy sports drinks        beverages
# 32434476              7      energy sports drinks        beverages
# 32434477              7      energy sports drinks        beverages
# 32434478              7      energy sports drinks        beverages
# 32434479              7      energy sports drinks        beverages
# 32434480              7      energy sports drinks        beverages
# 32434481              7      energy sports drinks        beverages
# 32434482              7      energy sports drinks        beverages
# 32434483              7      energy sports drinks        beverages
# 32434484              7      energy sports drinks        beverages
# 32434485              7      energy sports drinks        beverages
# 32434486             19    fruit vegetable snacks           snacks
# 32434487             19    fruit vegetable snacks           snacks
# 32434488             14  hot cereal pancake mixes        breakfast
#
# [32434489 rows x 15 columns]

# %%
orders_week_prod=orders_week[orders_week.department=='produce']
n1_week_produce=len(orders_week_prod)
n1_week_produce
# Out:
# 6186911

# %%
orders_weekend_prod=orders_weekend[orders_weekend.department=='produce']
n2_weekend_produce=len(orders_weekend_prod)
n2_weekend_produce
# Out:
# 3292380

# %%
#Proportion of orders with items from produce department
#proportion of produ calls
wc = n1_week_produce/n1
#proportion of black calls
bc = n2_weekend_produce/n2
wc,bc
diff = bc - wc
diff
# Out:
# 0.022623305498974067

# %%
wc,bc
# Out:
# (0.28478932030670046, 0.3074126258056745)

# %%
#calculate the p value
#pooled sample proportion
#Pooled sample proportion. Since the null hypothesis states that P1=P2, we use a pooled sample proportion (p) to compute the standard error of the sampling distribution.
#p = (p1 * n1 + p2 * n2) / (n1 + n2)
pooled  = (wc*n1+bc*n2)/(n1+n2)
pooled
# Out:
# 0.2922596067414535

# %%
# calculating the standard error
se_pooled = np.sqrt((pooled*(1 - pooled)/(n1)) + (pooled*(1 - pooled) /(n2)))


se_pooled_1 = np.sqrt( pooled * ( 1 - pooled ) * ((1/n1) + (1/n2) ))

# %%
se_pooled,se_pooled_1
# Out:
# (0.0001698070461738605, 0.0001698070461738605)

# %%
# calculate the statistic
z = (diff)/se_pooled #standard error calculated in CI above
p_values = stats.norm.sf(abs(z))*2 #twoside
print("Z-score : %0.1F  p-value : %0.9F" % (z,p_values))
# Out:
# Z-score : 133.2  p-value : 0.000000000

# %%
count = np.array([n1_week_produce, n2_weekend_produce])
nobs = np.array([n1, n2])
count,nobs
# Out:
# (array([6186911, 3292380]), array([21724519, 10709970]))

# %%
tstat,pval=ssp.proportions_ztest(count,nobs, value=0, alternative='two-sided', prop_var=False)
tstat,pval
# Out:
# (-133.22948610631104, 0.0)

# %% [markdown]
# Based on the p-value, we can say that there is difference between the proportion of orders with produce on weekend as compared to weekdays.
#
# The p-value can be 0 here because the data is probably not normally distributed.

# %% [markdown]
# ** Second Hypothesis test**
#
# Null Hypthesis  - There is no difference in number of reorderd items between items ordered on weekday versus items ordered on a weekend.
#
# Alternate Hypothesis - There is significant difference in number of reorderd items between items ordered on weekday versus items ordered on a weekend.

# %%
#create the order sets for weekdays and weekend
week = [1,2,3,4,5]
weekend = [0,6]
orders_week = orders_all[orders_all.order_dow.isin(week)]
orders_weekend = orders_all[orders_all.order_dow.isin(weekend)]

# %%
orders_week_re=orders_week[orders_week.reordered==1]
n1_week_re=len(orders_week_re)
n1_week_re
# Out:
# 12907335

# %%
orders_weekend_re=orders_weekend[orders_weekend.reordered==1]
n2_weekend_re=len(orders_weekend_re)
n2_weekend_re
# Out:
# 6219201

# %%
#proportion of reorders over the week 
wc = n1_week_re/n1
#proportion of reorders by weekend
bc = n2_weekend_re/n2
wc,bc
diff = bc - wc
diff
# Out:
# -0.0134440817490461

# %%
wc,bc
# Out:
# (0.5941367447537044, 0.5806926630046583)

# %%
#calculate the p value
#pooled sample proportion
#Pooled sample proportion. Since the null hypothesis states that P1=P2, we use a pooled sample proportion (p) to compute the standard error of the sampling distribution.
#p = (p1 * n1 + p2 * n2) / (n1 + n2)
pooled  = (wc*n1+bc*n2)/(n1+n2)
pooled
# Out:
# 0.5896974667922161

# %%
# calculating the standard error
se_pooled = np.sqrt((pooled*(1 - pooled)/(n1)) + (pooled*(1 - pooled) /(n2)))


se_pooled_1 = np.sqrt( pooled * ( 1 - pooled ) * ((1/n1) + (1/n2) ))

# %%
se_pooled,se_pooled_1
# Out:
# (0.00018365427765138162, 0.0001836542776513816)

# %%
# calculate the statistic
z = (diff)/se_pooled #standard error calculated in CI above
p_values = stats.norm.sf(abs(z))*2 #twoside
print("Z-score : %0.1F  p-value : %0.9F" % (z,p_values))
# Out:
# Z-score : -73.2  p-value : 0.000000000

# %% [markdown]
# Since the data does not have a normal distribution, the value is zero.

# %%
#Checking for correlation
orders_week_prod.head()
# Out:
#        order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 63885   2398795        1    prior             2          3                  7
# 63886    431534        1    prior             5          4                 15
# 63887   2168274        2    prior             1          2                 11
# 63888   3120740        7    prior            15          3                 16
# 63889   1468214       11    prior             7          5                  9
#
#        days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 63885                    15.0       13176                  4          0
# 63886                    28.0       13176                  8          1
# 63887                     NaN       13176                 12          0
# 63888                     2.0       13176                  8          0
# 63889                    30.0       13176                 12          0
#
#                  product_name  aisle_id  department_id         aisle  \
# 63885  Bag of Organic Bananas        24              4  fresh fruits
# 63886  Bag of Organic Bananas        24              4  fresh fruits
# 63887  Bag of Organic Bananas        24              4  fresh fruits
# 63888  Bag of Organic Bananas        24              4  fresh fruits
# 63889  Bag of Organic Bananas        24              4  fresh fruits
#
#       department
# 63885    produce
# 63886    produce
# 63887    produce
# 63888    produce
# 63889    produce

# %%
from scipy.stats import pearsonr
corr, p_value = pearsonr(orders_week_prod['order_dow'], orders_week_prod['order_hour_of_day'])

# %%
corr
# Out:
# 0.03141291423773683

# %% [markdown]
# They don't seem to be correlated
